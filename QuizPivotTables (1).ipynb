# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("antropometria-dataset-2.csv")
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
pivot_q1 = pd.pivot_table(df,
               index = 'desc_ent',
               #aggfunc = ['median'], #Funciones de pivot
               values = 'peso', #valores que queremos solamente
               #margins = True, # muestra todas las columnas
              )
pivot_q1
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# OAXACA                           58.800067
# ...

# %%
pivot_q2 = pd.pivot_table(df,
               index = 'desc_ent',
               aggfunc = 'median', 
               values = 'peso', 
               columns = 'sexo'
              )
pivot_q2
# Out:
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000
# BAJA CALIFORNIA                  70.6500  64.2000
# BAJA CALIFORNIA SUR              76.6500  68.5500
# CAMPECHE                         67.3500  62.3750
# CHIAPAS                          59.2000  56.0250
# CHIHUAHUA                        69.3000  64.6250
# COAHUILA DE ZARAGOZA             68.3000  67.3000
# COLIMA                           71.7000  66.0000
# DISTRITO FEDERAL                 69.0000  61.4500
# DURANGO                          70.3500  62.5000
# GUANAJUATO                       65.0625  60.3250
# GUERRERO                         60.5000  57.2000
# HIDALGO                          63.3000  57.9000
# JALISCO                          65.5875  63.3500
# MEXICO                           62.4500  56.9500
# MICHOACAN DE OCAMPO              67.6250  63.4000
# MORELOS                          65.2000  61.4500
# NAYARIT                          69.0500  63.7000
# ...

# %%
pivot_q3 = pd.pivot_table(df,
               index = 'desc_ent',
               aggfunc = 'mean', 
               values = 'peso', 
               columns = 'sexo'
              )
pivot_q3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_137/456870143.py in <module>
# ----> 1 pivot_q3 = pd.pivot_table(df,
#       2                index = 'desc_ent',
#       3                aggfunc = 'mean',
#       4                values = 'peso',
#       5                columns = 'sexo'
#
# NameError: name 'pd' is not defined

# %%
df_adult = pd.read_csv("adult.csv")
df_adult.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_79/3077976228.py in <module>
# ----> 1 df_adult = pd.read_csv("adult.csv")
#       2 df_adult.head()
#
# NameError: name 'pd' is not defined

# %%
pivot_q4 = pd.pivot_table(df_adult,
                          index = "marital-status",
                          values= "age",
                          aggfunc= "mean",
                          columns= "education"
                         )
pivot_q4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_79/3667109178.py in <module>
# ----> 1 pivot_q4 = pd.pivot_table(df_adult,
#       2                           index = "marital-status",
#       3                           values= "age",
#       4                           aggfunc= "mean",
#       5                           columns= "education"
#
# NameError: name 'pd' is not defined

# %%
pivot_q5 = pd.pivot_table(df_adult,
                          index = "marital-status",
                          values= "age",
                          aggfunc= "median",
                          columns= ("education", "sex"),
                         )
pivot_q5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_154/122964108.py in <module>
# ----> 1 pivot_q5 = pd.pivot_table(df_adult,
#       2                           index = "marital-status",
#       3                           values= "age",
#       4                           aggfunc= "median",
#       5                           columns= ("education", "sex"),
#
# NameError: name 'pd' is not defined
